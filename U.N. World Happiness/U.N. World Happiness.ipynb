# %% [markdown]
# ### Load Data and Setup ###

# %%
#install aimodelshare library
! pip install aimodelshare --upgrade
# Out:
# Requirement already satisfied: aimodelshare in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (0.0.178)
# Requirement already satisfied: onnx==1.12.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.12.0)
# Requirement already satisfied: wget==3.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (3.2)
# Requirement already satisfied: onnxconverter-common>=1.7.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.13.0)
# Requirement already satisfied: boto3==1.21.20 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.21.20)
# Requirement already satisfied: importlib-resources==5.10.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (5.10.0)
# Requirement already satisfied: psutil>=5.9.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (5.9.4)
# Requirement already satisfied: onnxmltools>=1.6.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.11.1)
# Requirement already satisfied: keras2onnx>=1.7.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.7.0)
# Requirement already satisfied: regex in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (2022.7.9)
# Requirement already satisfied: docker==5.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (5.0.0)
# Requirement already satisfied: astunparse==1.6.3 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.6.3)
# Requirement already satisfied: shortuuid>=1.0.8 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.0.11)
# Requirement already satisfied: tf2onnx in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.13.0)
# Requirement already satisfied: skl2onnx>=1.8.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.13)
# Requirement already satisfied: pathlib>=1.0.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.0.1)
# Requirement already satisfied: Pympler==0.9 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (0.9)
# Requirement already satisfied: seaborn>=0.11.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (0.12.2)
# Requirement already satisfied: scikit-learn==0.24.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (0.24.2)
# Requirement already satisfied: botocore==1.24.20 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.24.20)
# Requirement already satisfied: PyJWT>=2.4.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (2.6.0)
# Requirement already satisfied: tensorflow==2.9.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (2.9.2)
# Requirement already satisfied: onnxruntime>=1.7.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.13.1)
# Requirement already satisfied: torch>=1.8.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.13.1)
# Requirement already satisfied: pydot==1.3.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from aimodelshare) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from astunparse==1.6.3->aimodelshare) (0.37.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from astunparse==1.6.3->aimodelshare) (1.16.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from boto3==1.21.20->aimodelshare) (0.5.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from boto3==1.21.20->aimodelshare) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from botocore==1.24.20->aimodelshare) (1.26.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from botocore==1.24.20->aimodelshare) (2.8.2)
# Requirement already satisfied: requests!=2.18.0,>=2.14.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from docker==5.0.0->aimodelshare) (2.28.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from docker==5.0.0->aimodelshare) (0.58.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources==5.10.0->aimodelshare) (3.11.0)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from onnx==1.12.0->aimodelshare) (3.19.6)
# Requirement already satisfied: numpy>=1.16.6 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from onnx==1.12.0->aimodelshare) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from onnx==1.12.0->aimodelshare) (4.4.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from pydot==1.3.0->aimodelshare) (3.0.9)
# Requirement already satisfied: scipy>=0.19.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn==0.24.2->aimodelshare) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn==0.24.2->aimodelshare) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn==0.24.2->aimodelshare) (2.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (1.12)
# Requirement already satisfied: libclang>=13.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (15.0.6.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (1.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (1.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (0.30.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (3.7.0)
# Requirement already satisfied: packaging in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (22.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (0.4.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (2.9.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (2.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (1.51.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (1.14.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (2.9.0)
# Requirement already satisfied: setuptools in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorflow==2.9.2->aimodelshare) (65.6.3)
# Requirement already satisfied: fire in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from keras2onnx>=1.7.0->aimodelshare) (0.5.0)
# Requirement already satisfied: coloredlogs in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from onnxruntime>=1.7.0->aimodelshare) (15.0.1)
# Requirement already satisfied: sympy in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from onnxruntime>=1.7.0->aimodelshare) (1.11.1)
# Requirement already satisfied: pandas>=0.25 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from seaborn>=0.11.2->aimodelshare) (1.5.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from seaborn>=0.11.2->aimodelshare) (3.6.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare) (9.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn>=0.11.2->aimodelshare) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->seaborn>=0.11.2->aimodelshare) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from requests!=2.18.0,>=2.14.2->docker==5.0.0->aimodelshare) (3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.6)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from coloredlogs->onnxruntime>=1.7.0->aimodelshare) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from sympy->onnxruntime>=1.7.0->aimodelshare) (1.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (4.11.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.2->aimodelshare) (3.2.2)

# %%
#Get competition data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile
  
# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:
  
    # Extracting all the members of the zip 
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %% [markdown]
# ### Explore bivariate results (Use visualizations!) ###
# Describe any relationships you see between particular features and the target variable

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.set()
area = pd.DataFrame(X_train)

sns.pairplot(area, height = 2.5,kind='reg')
plt.show()

# %% [markdown]
# From the above graph, it can be seen that there is a strong positive relationship between GDP per capita vs. Healthy life expectancy; social support vs. Healthy life expectancy; social support vs. GDP per capita as the graphs show slope-up pattern.

# %% [markdown]
# ### Examine features that predict happiness categories using one or more models that allow for automatic feature selection ###
# Explain any meaningful findings

# %% [markdown]
# ### Preprocess data using Sklearn ###

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocessor(data):
    data.drop(['Country or region', 'name'], axis=1)
    preprocessed_data=preprocess.transform(data)
    return preprocessed_data

# %%
# check shape of X data after preprocessing it using our new function
preprocessor(X_train).shape
# Out:
# (88, 26)

# %%
#Feature selection using RFE
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

estimator = LinearRegression().fit(preprocessor(X_train), y_train) #model with all X variables


selector = RFE(estimator, n_features_to_select=3, step=1) # step tells RFE how many features to remove each time model features are evaluated

selector = selector.fit(preprocessor(X_train), y_train) # fit RFE estimator.

print("Num Features: "+str(selector.n_features_))
print("Selected Features: "+str(selector.support_)) 
print("Feature Ranking: "+str(selector.ranking_))
# Out:
# Num Features: 3
# Selected Features: [False False False False False False False False False False False  True
#  False False False False False False  True False False False False False
#  False  True]
# Feature Ranking: [10 24 19 23 16 21 18 22 17 13 20  1  9  6  5  4  7  3  1  2 15 11  8 12
#  14  1]

# %%
# Transform X data for other use in this model or other models:

X_new = selector.transform(preprocessor(X_train)) #reduces X to subset identified above
X_new_test=selector.transform(preprocessor(X_test))

# %% [markdown]
# Using RFE we are able to eliminate to the selected three features.

# %% [markdown]
# ### Experiment with different prediction models to try to predict World Happiness well (Fit and compare, at minimum, three models) ###
# submit three models to the model share leaderboard before you start communicating with your team.
# After you submit your first three models, describe your best model with your team via your team slack channel
# Fit and submit up to three more models after learning from your team.
# Discuss which models you tried and which models performed better and point out relevant hyper-parameter values for successful models.
# Submit your best models to the leaderboard for the World Happiness AI Model Share competition.
# You have the option to present and/or discuss these models in your report, but it is not required.

# %%
#model 1: random forest with gridsearch
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import numpy as np

param_grid = {'n_estimators': np.arange(25, 50, 100),'max_depth':[1,3,5]} #np.arange creates sequence of numbers for each k value

gridmodel = GridSearchCV(RandomForestClassifier(), param_grid=param_grid, cv=15)

#use meta model methods to fit score and predict model:
gridmodel.fit(X_new, y_train_labels)

#extract best score and parameter by calling objects "best_score_" and "best_params_"
print("best mean cross-validation score: {:.3f}".format(gridmodel.best_score_))
print("best parameters: {}".format(gridmodel.best_params_))
# Out:
# best mean cross-validation score: 0.293
# best parameters: {'max_depth': 1, 'n_estimators': 25}

# %%
import aimodelshare as ai
ai.export_preprocessor(preprocessor,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx
from skl2onnx.common.data_types import FloatTensorType

feature_count=X_new_test.shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(gridmodel, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("gridmodel.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials
#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://e2w6gh3id1.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# AI Modelshare Username:········
# AI Modelshare Password:········
# AI Model Share login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.Competition(apiurl)

# %%
#Submit Model 1: 

#-- Generate predicted values
prediction_labels = gridmodel.predict(X_new_test)

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "gridmodel.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 100% [......................................................] 1531245 / 1531245
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# 100% [......................................................] 1842473 / 1842473
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 781
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
# Model 2: Gradient Boosted Classifier 
from sklearn.ensemble import GradientBoostingClassifier

model_2 = GradientBoostingClassifier(n_estimators=100, learning_rate=0.5,
    max_depth=5, random_state=0).fit(X_new, y_train_labels)
model_2.score(X_new, y_train_labels)
# Out:
# 0.3181818181818182

# %%
# Save sklearn model to local ONNX file
from aimodelshare.aimsonnx import model_to_onnx

feature_count=X_new_test.shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#Submit Model 2: 

#-- Generate predicted y values (Model 2)
prediction_labels = model_2.predict(X_new_test)

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model2.onnx",
                                 prediction_submission=prediction_labels,
                                 preprocessor_filepath="preprocessor.zip")
# Out:
# 100% [......................................................] 1532811 / 1532811
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# 100% [......................................................] 1842473 / 1842473
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 782
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
#model 3

import tensorflow.keras as keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.optimizers import SGD

feature_count=X_new.shape[1] #count features in input data

keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(5, activation='softmax')) 
                                            
# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
from aimodelshare.aimsonnx import model_to_onnx

onnx_model = model_to_onnx(keras_model, framework='keras',
                          transfer_learning=False,
                          deep_learning=True)

with open("model.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())
# Out:
# /Users/moonliang/opt/anaconda3/lib/python3.8/runpy.py:127: RuntimeWarning: 'tf2onnx.convert' found in sys.modules after import of package 'tf2onnx', but prior to execution of 'tf2onnx.convert'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# 2023-02-07 13:30:57,966 - WARNING - '--tag' not specified for saved_model. Using --tag serve
# 2023-02-07 13:30:58,214 - INFO - Signatures found in model: [serving_default].
# 2023-02-07 13:30:58,214 - WARNING - '--signature_def' not specified, using first signature: serving_default
# 2023-02-07 13:30:58,214 - INFO - Output names: ['dense_4']
# 2023-02-07 13:30:58,296 - INFO - Using tensorflow=2.9.2, onnx=1.12.0, tf2onnx=1.13.0/2c1db5
# 2023-02-07 13:30:58,296 - INFO - Using opset <onnx, 13>
# 2023-02-07 13:30:58,312 - INFO - Computed 0 values for constant folding
# 2023-02-07 13:30:58,333 - INFO - Optimizing ONNX model
# 2023-02-07 13:30:58,387 - INFO - After optimization: Identity -2 (2->0)
# 2023-02-07 13:30:58,389 - INFO -
# 2023-02-07 13:30:58,389 - INFO - Successfully converted TensorFlow model /var/folders/5c/hf6jh6rx6f748yvyh07whc6h0000gn/T/tmpt8p2hzz9 to ONNX
# 2023-02-07 13:30:58,389 - INFO - Model inputs: ['dense_input']
# 2023-02-07 13:30:58,389 - INFO - Model outputs: ['dense_4']
# 2023-02-07 13:30:58,389 - INFO - ONNX model is saved at /var/folders/5c/hf6jh6rx6f748yvyh07whc6h0000gn/T/tmpt8p2hzz9/temp.onnx

# %%
# Submit keras model: 

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models
prediction_column_index=keras_model.predict(X_new_test).argmax(axis=1)

# extract correct prediction labels 
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 3/3 [==============================] - 0s 1ms/step
# 100% [......................................................] 1534420 / 1534420
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# 100% [......................................................] 1842473 / 1842473
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 783
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
data=mycompetition.compare_models([1,2,3,4,5], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/aimsonnx.py:1244: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   display(HTML(df_styled.render()))
# <style type="text/css">
# #T_4540e caption {
#   color: black;
#   font-size: 18px;
# }
# #T_4540e_row0_col0, #T_4540e_row1_col0, #T_4540e_row2_col0, #T_4540e_row3_col0 {
#   background: #fff2ae;
#   color: black;
#   color: black;
# }
# #T_4540e_row0_col1, #T_4540e_row0_col2, #T_4540e_row1_col1, #T_4540e_row1_col2, #T_4540e_row2_col1, #T_4540e_row2_col2, #T_4540e_row3_col1, #T_4540e_row3_col2 {
#   background: white;
#   color: black;
#   color: black;
# }
# </style>
# <table id="T_4540e">
#   <caption>Model type: Neural Network</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4540e_level0_col0" class="col_heading level0 col0" >Model_1_Layer</th>
#       <th id="T_4540e_level0_col1" class="col_heading level0 col1" >Model_1_Shape</th>
#       <th id="T_4540e_level0_col2" class="col_heading level0 col2" >Model_1_Params</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4540e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4540e_row0_col0" class="data row0 col0" >Dense</td>
#       <td id="T_4540e_row0_col1" class="data row0 col1" >[None, 64]</td>
#       <td id="T_4540e_row0_col2" class="data row0 col2" >1728</td>
#     </tr>
#     <tr>
#       <th id="T_4540e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4540e_row1_col0" class="data row1 col0" >Dense</td>
#       <td id="T_4540e_row1_col1" class="data row1 col1" >[None, 64]</td>
#       <td id="T_4540e_row1_col2" class="data row1 col2" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_4540e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4540e_row2_col0" class="data row2 col0" >Dense</td>
#       <td id="T_4540e_row2_col1" class="data row2 col1" >[None, 64]</td>
#       <td id="T_4540e_row2_col2" class="data row2 col2" >4160</td>
#     </tr>
#     <tr>
#       <th id="T_4540e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4540e_row3_col0" class="data row3 col0" >Dense</td>
#       <td id="T_4540e_row3_col1" class="data row3 col1" >[None, 5]</td>
#       <td id="T_4540e_row3_col2" class="data row3 col2" >325</td>
#     </tr>
#   </tbody>
# </table>
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/aimsonnx.py:1268: FutureWarning: this method is deprecated in favour of `Styler.to_html()`
#   display(HTML(df_styled.render()))
# <style type="text/css">
# #T_3fc2a caption {
#   color: black;
#   font-size: 18px;
# }
# #T_3fc2a_row4_col2, #T_3fc2a_row4_col3, #T_3fc2a_row4_col4, #T_3fc2a_row13_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_3fc2a">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fc2a_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_3fc2a_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_3fc2a_level0_col2" class="col_heading level0 col2" >model_version_2</th>
#       <th id="T_3fc2a_level0_col3" class="col_heading level0 col3" >model_version_3</th>
#       <th id="T_3fc2a_level0_col4" class="col_heading level0 col4" >model_version_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fc2a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fc2a_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_3fc2a_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_3fc2a_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_3fc2a_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_3fc2a_row0_col4" class="data row0 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fc2a_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_3fc2a_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_3fc2a_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_3fc2a_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_3fc2a_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3fc2a_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_3fc2a_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_3fc2a_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_3fc2a_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_3fc2a_row2_col4" class="data row2 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3fc2a_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_3fc2a_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_3fc2a_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_3fc2a_row3_col3" class="data row3 col3" >gini</td>
#       <td id="T_3fc2a_row3_col4" class="data row3 col4" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3fc2a_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_3fc2a_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_3fc2a_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_3fc2a_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_3fc2a_row4_col4" class="data row4 col4" >5</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3fc2a_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_3fc2a_row5_col1" class="data row5 col1" >auto</td>
#       <td id="T_3fc2a_row5_col2" class="data row5 col2" >auto</td>
#       <td id="T_3fc2a_row5_col3" class="data row5 col3" >auto</td>
#       <td id="T_3fc2a_row5_col4" class="data row5 col4" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3fc2a_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_3fc2a_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_3fc2a_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_3fc2a_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_3fc2a_row6_col4" class="data row6 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3fc2a_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_3fc2a_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_3fc2a_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_3fc2a_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_3fc2a_row7_col4" class="data row7 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3fc2a_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_3fc2a_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_3fc2a_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_3fc2a_row8_col3" class="data row8 col3" >0.000000</td>
#       <td id="T_3fc2a_row8_col4" class="data row8 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3fc2a_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_3fc2a_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_3fc2a_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_3fc2a_row9_col3" class="data row9 col3" >None</td>
#       <td id="T_3fc2a_row9_col4" class="data row9 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3fc2a_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_3fc2a_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_3fc2a_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_3fc2a_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_3fc2a_row10_col4" class="data row10 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3fc2a_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_3fc2a_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_3fc2a_row11_col2" class="data row11 col2" >2</td>
#       <td id="T_3fc2a_row11_col3" class="data row11 col3" >2</td>
#       <td id="T_3fc2a_row11_col4" class="data row11 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3fc2a_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_3fc2a_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_3fc2a_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_3fc2a_row12_col3" class="data row12 col3" >0.000000</td>
#       <td id="T_3fc2a_row12_col4" class="data row12 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3fc2a_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_3fc2a_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_3fc2a_row13_col2" class="data row13 col2" >300</td>
#       <td id="T_3fc2a_row13_col3" class="data row13 col3" >100</td>
#       <td id="T_3fc2a_row13_col4" class="data row13 col4" >100</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3fc2a_row14_col0" class="data row14 col0" >n_jobs</td>
#       <td id="T_3fc2a_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_3fc2a_row14_col2" class="data row14 col2" >None</td>
#       <td id="T_3fc2a_row14_col3" class="data row14 col3" >None</td>
#       <td id="T_3fc2a_row14_col4" class="data row14 col4" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3fc2a_row15_col0" class="data row15 col0" >oob_score</td>
#       <td id="T_3fc2a_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_3fc2a_row15_col2" class="data row15 col2" >False</td>
#       <td id="T_3fc2a_row15_col3" class="data row15 col3" >False</td>
#       <td id="T_3fc2a_row15_col4" class="data row15 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3fc2a_level0_row16" class="row_heading level0 row16" >16</th>
#       <t
# <style type="text/css">
# #T_3eeeb caption {
#   color: black;
#   font-size: 18px;
# }
# #T_3eeeb_row3_col2, #T_3eeeb_row5_col2, #T_3eeeb_row13_col2, #T_3eeeb_row15_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_3eeeb">
#   <caption>Model type: GradientBoostingClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eeeb_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_3eeeb_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_3eeeb_level0_col2" class="col_heading level0 col2" >model_version_5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eeeb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3eeeb_row0_col0" class="data row0 col0" >ccp_alpha</td>
#       <td id="T_3eeeb_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_3eeeb_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3eeeb_row1_col0" class="data row1 col0" >criterion</td>
#       <td id="T_3eeeb_row1_col1" class="data row1 col1" >friedman_mse</td>
#       <td id="T_3eeeb_row1_col2" class="data row1 col2" >friedman_mse</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3eeeb_row2_col0" class="data row2 col0" >init</td>
#       <td id="T_3eeeb_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_3eeeb_row2_col2" class="data row2 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3eeeb_row3_col0" class="data row3 col0" >learning_rate</td>
#       <td id="T_3eeeb_row3_col1" class="data row3 col1" >0.100000</td>
#       <td id="T_3eeeb_row3_col2" class="data row3 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3eeeb_row4_col0" class="data row4 col0" >loss</td>
#       <td id="T_3eeeb_row4_col1" class="data row4 col1" >deviance</td>
#       <td id="T_3eeeb_row4_col2" class="data row4 col2" >deviance</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3eeeb_row5_col0" class="data row5 col0" >max_depth</td>
#       <td id="T_3eeeb_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_3eeeb_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3eeeb_row6_col0" class="data row6 col0" >max_features</td>
#       <td id="T_3eeeb_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_3eeeb_row6_col2" class="data row6 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3eeeb_row7_col0" class="data row7 col0" >max_leaf_nodes</td>
#       <td id="T_3eeeb_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_3eeeb_row7_col2" class="data row7 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3eeeb_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_3eeeb_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_3eeeb_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3eeeb_row9_col0" class="data row9 col0" >min_impurity_split</td>
#       <td id="T_3eeeb_row9_col1" class="data row9 col1" >None</td>
#       <td id="T_3eeeb_row9_col2" class="data row9 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3eeeb_row10_col0" class="data row10 col0" >min_samples_leaf</td>
#       <td id="T_3eeeb_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_3eeeb_row10_col2" class="data row10 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3eeeb_row11_col0" class="data row11 col0" >min_samples_split</td>
#       <td id="T_3eeeb_row11_col1" class="data row11 col1" >2</td>
#       <td id="T_3eeeb_row11_col2" class="data row11 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3eeeb_row12_col0" class="data row12 col0" >min_weight_fraction_leaf</td>
#       <td id="T_3eeeb_row12_col1" class="data row12 col1" >0.000000</td>
#       <td id="T_3eeeb_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3eeeb_row13_col0" class="data row13 col0" >n_estimators</td>
#       <td id="T_3eeeb_row13_col1" class="data row13 col1" >100</td>
#       <td id="T_3eeeb_row13_col2" class="data row13 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3eeeb_row14_col0" class="data row14 col0" >n_iter_no_change</td>
#       <td id="T_3eeeb_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_3eeeb_row14_col2" class="data row14 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3eeeb_row15_col0" class="data row15 col0" >random_state</td>
#       <td id="T_3eeeb_row15_col1" class="data row15 col1" >None</td>
#       <td id="T_3eeeb_row15_col2" class="data row15 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3eeeb_row16_col0" class="data row16 col0" >subsample</td>
#       <td id="T_3eeeb_row16_col1" class="data row16 col1" >1.000000</td>
#       <td id="T_3eeeb_row16_col2" class="data row16 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3eeeb_row17_col0" class="data row17 col0" >tol</td>
#       <td id="T_3eeeb_row17_col1" class="data row17 col1" >0.000100</td>
#       <td id="T_3eeeb_row17_col2" class="data row17 col2" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3eeeb_row18_col0" class="data row18 col0" >validation_fraction</td>
#       <td id="T_3eeeb_row18_col1" class="data row18 col1" >0.100000</td>
#       <td id="T_3eeeb_row18_col2" class="data row18 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3eeeb_row19_col0" class="data row19 col0" >verbose</td>
#       <td id="T_3eeeb_row19_col1" class="data row19 col1" >0</td>
#       <td id="T_3eeeb_row19_col2" class="data row19 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_3eeeb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3eeeb_row20_col0" class="data row20 col0" >warm_start</td>
#       <td id="T_3eeeb_row20_col1" class="data row20 col1" >False</td>
#       <td id="T_3eeeb_row20_col2" class="data row20 col2" >False</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Feature selection using RFE
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

estimator = LinearRegression().fit(preprocessor(X_train), y_train) #model with all X variables


selector = RFE(estimator, n_features_to_select=9, step=1) # step tells RFE how many features to remove each time model features are evaluated

selector = selector.fit(preprocessor(X_train), y_train) # fit RFE estimator.

print("Num Features: "+str(selector.n_features_))
print("Selected Features: "+str(selector.support_)) 
print("Feature Ranking: "+str(selector.ranking_))
# Out:
# Num Features: 9
# Selected Features: [False False False False False False False False False False False  True
#  False  True  True  True  True  True  True  True False False False False
#  False  True]
# Feature Ranking: [ 4 18 13 17 10 15 12 16 11  7 14  1  3  1  1  1  1  1  1  1  9  5  2  6
#   8  1]

# %%
# Transform X data for other use in this model or other models:

X_new2 = selector.transform(preprocessor(X_train)) #reduces X to subset identified above
X_new_test2=selector.transform(preprocessor(X_test))

# %%
# Model :Gradient Boosted Classifier 
from sklearn.ensemble import GradientBoostingClassifier

model_2 = GradientBoostingClassifier(n_estimators=150, learning_rate=0.5,
    max_depth=5, random_state=0).fit(X_new2, y_train_labels)
model_2.score(X_new2, y_train_labels)
# Out:
# 0.5113636363636364

# %% [markdown]
# I tried three models, the Gradient boosting classifier  performed best
#
# 1. Random forest classifier with gridsearchcv: max depth [3,5,7] 'n_estimators': (300,500, 700), cv=15 best parameters: max depth=3, n_estimators: 300
# 2. Gradient boosting classifier with learning_rate: 0.5, max_depth: 5, n_estimators: 100, random_state: 0 (best score in my model)
# 3. Neural network with four layers (dense=128, 64, 64, 64 ,5) batch_size= 20, epochs= 300, validation_split= 0.25
#
# After discussing with my team, Gradient boosting classifier seems to have the highest accuracy and I changed the number of selected features to 9, used RFE to eliminate. Then run the Gradient boosting classifier again to get the highest score. with the parameters of learning_rate: 0.5, max_depth: 5, n_estimators: 100, random_state: 0.

# %%
from aimodelshare.aimsonnx import model_to_onnx

feature_count=X_new_test2.shape[1] #Get count of preprocessed features
initial_type = [('float_input', FloatTensorType([None, feature_count]))]  # Insert correct number of preprocessed features

onnx_model = model_to_onnx(model_2, framework='sklearn',
                          initial_types=initial_type,
                          transfer_learning=False,
                          deep_learning=False)

with open("model_2.onnx", "wb") as f:
    f.write(onnx_model.SerializeToString())

# %%
#-- Generate predicted values
prediction_labels = model_2.predict(X_new_test2)

# Submit to Competition Leaderboard
mycompetition.submit_model(model_filepath = "model_2.onnx",
                                 preprocessor_filepath="preprocessor.zip",
                                 prediction_submission=prediction_labels,
                          custom_metadata={"team":"3"})
# Out:
# 100% [......................................................] 1539535 / 1539535
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# 100% [......................................................] 1842473 / 1842473
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:302: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   leaderboard = leaderboard.append(metadata, ignore_index=True, sort=False)
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:304: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['username']=leaderboard.pop("username")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:305: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['timestamp'] = leaderboard.pop("timestamp")
# /Users/moonliang/opt/anaconda3/lib/python3.8/site-packages/aimodelshare/model.py:306: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   leaderboard['version'] = leaderboard.pop("version")
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
#
# Your model has been submitted as model version 785
#
# To submit code used to create this model or to view current leaderboard navigate to Model Playground:
#
#  https://www.modelshare.org/detail/model:3164

# %%
data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_849a1_row0_col0, #T_849a1_row4_col0, #T_849a1_row5_col0, #T_849a1_row6_col0, #T_849a1_row7_col0, #T_849a1_row8_col0, #T_849a1_row9_col0, #T_849a1_row20_col0, #T_849a1_row23_col0, #T_849a1_row24_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 55.9%, transparent 55.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_849a1_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 53.9%, transparent 53.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_849a1_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 68.2%, transparent 68.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_849a1_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 58.1%, transparent 58.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_849a1_row0_col4, #T_849a1_row0_col5, #T_849a1_row0_col6, #T_849a1_row0_col7, #T_849a1_row0_col8, #T_849a1_row0_col9, #T_849a1_row0_col10, #T_849a1_row0_col11, #T_849a1_row0_col12, #T_849a1_row0_col13, #T_849a1_row0_col14, #T_849a1_row0_col15, #T_849a1_row0_col16, #T_849a1_row0_col17, #T_849a1_row0_col18, #T_849a1_row0_col19, #T_849a1_row0_col20, #T_849a1_row0_col21, #T_849a1_row0_col22, #T_849a1_row1_col4, #T_849a1_row1_col5, #T_849a1_row1_col6, #T_849a1_row1_col7, #T_849a1_row1_col8, #T_849a1_row1_col9, #T_849a1_row1_col10, #T_849a1_row1_col11, #T_849a1_row1_col12, #T_849a1_row1_col13, #T_849a1_row1_col14, #T_849a1_row1_col15, #T_849a1_row1_col16, #T_849a1_row1_col17, #T_849a1_row1_col18, #T_849a1_row1_col19, #T_849a1_row1_col20, #T_849a1_row1_col21, #T_849a1_row1_col22, #T_849a1_row2_col4, #T_849a1_row2_col5, #T_849a1_row2_col6, #T_849a1_row2_col7, #T_849a1_row2_col8, #T_849a1_row2_col9, #T_849a1_row2_col10, #T_849a1_row2_col11, #T_849a1_row2_col12, #T_849a1_row2_col13, #T_849a1_row2_col14, #T_849a1_row2_col15, #T_849a1_row2_col16, #T_849a1_row2_col17, #T_849a1_row2_col18, #T_849a1_row2_col19, #T_849a1_row2_col20, #T_849a1_row2_col21, #T_849a1_row2_col22, #T_849a1_row3_col4, #T_849a1_row3_col5, #T_849a1_row3_col6, #T_849a1_row3_col7, #T_849a1_row3_col8, #T_849a1_row3_col9, #T_849a1_row3_col10, #T_849a1_row3_col11, #T_849a1_row3_col12, #T_849a1_row3_col13, #T_849a1_row3_col14, #T_849a1_row3_col15, #T_849a1_row3_col16, #T_849a1_row3_col17, #T_849a1_row3_col18, #T_849a1_row3_col19, #T_849a1_row3_col20, #T_849a1_row3_col21, #T_849a1_row3_col22, #T_849a1_row4_col4, #T_849a1_row4_col5, #T_849a1_row4_col6, #T_849a1_row4_col7, #T_849a